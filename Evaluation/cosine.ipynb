# %%
import pandas as pd
df=pd.read_csv('/content/GeneratedAbstract_A61B.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
gen = df['generated_abstract'].astype(str).tolist()
ref = df['patent_abstract'].astype(str).tolist()
a=[]
for i in range(len(gen)):
  documents = [ref[i], gen[i]]
  tfidf_vectorizer = TfidfVectorizer()
  tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
  cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]
  a.append(cosine_sim)
df.loc[:, 'cosine_similarity'] = a

df.to_csv('Evaluation_abstract_A61B_cosine.csv', index=False)
